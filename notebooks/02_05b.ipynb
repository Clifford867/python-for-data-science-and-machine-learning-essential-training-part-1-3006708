# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame

# %% [markdown]
# ### Removing duplicates

# %%
# %pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.2.0
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2026.2.25
# cffi                      2.0.0
# charset-normalizer        3.4.5
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# gitdb                     4.0.12
# GitPython                 3.1.46
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# ...

# %%
df_obj = DataFrame({'column 1': [1,1,2,3,3,3,3],
                    'column 2': ['a', 'a', 'b', 'b', 'c', 'c', 'c'],
                    'column 3': ['A', 'A', 'B', 'B', 'C', 'D', 'C']})

df_obj
# Out:
#    column 1 column 2 column 3
# 0         1        a        A
# 1         1        a        A
# 2         2        b        B
# 3         3        b        B
# 4         3        c        C
# 5         3        c        D
# 6         3        c        C

# %%
df_obj.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
df_obj.drop_duplicates(['column 3'])
# Out:
#    column 1 column 2 column 3
# 0         1        a        A
# 2         2        b        B
# 4         3        c        C
# 5         3        c        D
